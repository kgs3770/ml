# %%
#선형 회귀***

# %%
import pandas as pd

df = pd.read_csv('data/Fish.csv')

# %%
perch_df = df.loc[df['Species'] == 'Perch']

perch_length = perch_df[['Length2']]
perch_weight = perch_df[['Weight']]

# %%
#데이터 나누기
from sklearn.model_selection import train_test_split

train_input, test_input, train_target, test_target = train_test_split(perch_length, perch_weight)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

lr.fit(train_input, train_target)
# Out:
# LinearRegression()

# %%
lr.score(test_input, test_target)
# Out:
# 0.9293321936121914

# %%
#기울기 or 가중치
lr.coef_
# Out:
# array([[36.01580136]])

# %%
#y축
lr.intercept_
# Out:
# array([-631.52089672])

# %%
import matplotlib.pyplot as plt

plt.scatter(train_input, train_target)

#선그래프 그리기
plt.plot([15, 50], [15 * 37 - 667, 50 * 37 - 667])

# %%
print(lr.score(train_input, train_target))
print(lr.score(test_input, test_target))
# Out:
# 0.9054496618113339
# 0.9293321936121914

# %%
#100cm짜리 예측해봐
lr.predict([[100]])
# Out:
# C:\Users\1-02\Desktop\DAMF2\ml\venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[2970.0592396]])

# %%
#다항 회귀
#그래프를 곡선의 형태로 만들거임

# %%
#학습 하려는 데이터를 제곱 후 train input에 넣어줌
train_input['Length2_poly'] = train_input['Length2'] ** 2
test_input['Length2_poly'] = test_input['Length2'] ** 2

# %%
lr = LinearRegression()
lr.fit(train_input, train_target)
# Out:
# LinearRegression()

# %%
lr.score(test_input, test_target)
# Out:
# 0.9364012807168363

# %%
lr.predict([[2, 4]]) #[x, x**2]
# Out:
# C:\Users\1-02\Desktop\DAMF2\ml\venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[134.49506026]])

# %%
print(lr.coef_, lr.intercept_)
# Out:
# [[-27.59876884   1.12829874]] [185.17940299]

# %%
import numpy as np

point = np.arange(15, 50)
# train_input
plt.scatter(train_input['Length2'], train_target)

plt.plot(point, (float(lr.coef_[0][1]) * point ** 2) + (float(lr.coef_[0][0]) * point) + float(lr.intercept_[0]))

# %%
print(lr.predict([[1, 1]]))
print(lr.predict([[3, 9]]))
# Out:
# [[158.70893289]]
# [[112.53778511]]
# C:\Users\1-02\Desktop\DAMF2\ml\venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\1-02\Desktop\DAMF2\ml\venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
